# %% [markdown]
# # World Population by Country
# **2023 World Population 8,005,176,000**

# %% [markdown]
# ## Introduction

# %% [markdown]
# We Know The World is full of many living and non living creations and Human Being is the top most living creation in the world. So,The World Population is the total number of human beings currently living in present.The Human population has experienced continuous growth. It took around 300,000 years of human prehistory & history for the human population to reach one billion.
#
# The US Census Bureau's world population clock estimated that the global population as of September 2022 was 7,922,312,800 people and was expected to reach 8 billion by mid-November of 2022. This total far exceeds the 2015 world population of 7.2 billion. The world's population continues to increase by roughly 140 people per minute, with births outweighing deaths in most countries.
#
# Overall, however, the rate of population growth has been slowing for several decades. This slowdown is expected to continue until the rate of population growth reaches zero (an equal number of births and deaths) around 2080-2100, at a population of approximately 10.4 billion people. After this time, the population growth rate is expected to turn negative, resulting in global population decline.
#
# Countries with more than 1 billion people China is currently the most populous country in the world, with a population estimated at more than 1.42 billion as of September 2022. Only one other country in the world boasts a population of more than 1 billion people: India, whose population is estimated to be 1.41 billion people—and rising.

# %% [markdown]
# ## Purpose of Analysis

# %% [markdown]
# Analyzing world population data by countries serves several important purposes, providing valuable insights for various fields and decision-making processes. Here are some key purposes of data analysis on world population by countries:\
# **Policy Formulation and Governance:**
#
# One of the primary purposes is to inform the development and implementation of effective policies. Governments use population data to understand the needs of their citizens, allocate resources, and formulate policies related to healthcare, education, social welfare, and economic development.\
# **Resource Allocation and Planning:**
#
# Population data guides resource allocation by helping governments and organizations plan infrastructure, healthcare facilities, schools, and other public services. It aids in identifying areas that require specific attention and investment to meet the needs of the population.\
# **Economic Decision-Making:**
#
# Businesses, policymakers, and economists analyze population data to make informed decisions about economic planning. This includes forecasting labor force trends, consumer demand, and overall economic growth, which is crucial for shaping economic policies and strategies.\
# **Healthcare Management:**
#
# Population data analysis is vital for healthcare planning and management. It assists in identifying health trends, disease prevalence, and healthcare needs, allowing for the development of targeted healthcare programs, infrastructure, and resource allocation.\
# **Global Development Initiatives:**
#
# International organizations and NGOs use world population data to prioritize and implement global development initiatives. By understanding population dynamics, they can focus on regions that need assistance, plan sustainable development projects, and address issues such as poverty, hunger, and healthcare on a global scale.\
# In summary, data analysis of world population by countries plays a fundamental role in informed decision-making across various sectors, contributing to the well-being and sustainable development of societies globally.

# %% [markdown]
# **Data Collection**

# %% [markdown]
# We are going to consider a dataset of World Population by Country . It contains population of each country in  2000, 2010, 2022, 2023, 2030, 2050, along with growth rate of each country, density per km etc.\
# We will use Python libraries (Pandas, Numpy, Matplotlib) to analyze the database.
# The dataset can be downloaded here.
# [Link](https://github.com/AnudipAE/DANLC/blob/master/cleaned.csv)\
# In this analysis, we will be using Jupyter Notebook.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# **1. Loading the Dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('countries_table.csv')
print(data.head())
# Out:
#          country  rank       area  landAreaKm  netChange  growthRate  \
# 0          India     1  3287590.0   2973190.0     0.4184      0.0081
# 1          China     2  9706961.0   9424702.9    -0.0113     -0.0002
# 2  United States     3  9372610.0   9147420.0     0.0581      0.0050
# 3      Indonesia     4  1904569.0   1877519.0     0.0727      0.0074
# 4       Pakistan     5   881912.0    770880.0     0.1495      0.0198
#
#    worldPercentage   density  place     pop2000     pop2010     pop2022  \
# 0           0.1785  480.5033    356  1059633675  1240613620  1417173173
# 1           0.1781  151.2696    156  1264099069  1348191368  1425887337
# 2           0.0425   37.1686    840   282398554   311182845   338289857
# 3           0.0347  147.8196    360   214072421   244016173   275501339
# 4           0.0300  311.9625    586   154369924   194454498   235824862
#
#       pop2023     pop2030     pop2050
# 0  1428627663  1514994080  1670490596
# 1  1425671352  1415605906  1312636325
# ...

# %% [markdown]
# **2. Explore the dataset**

# %%
data = pd.read_csv('countries_table.csv')
print("Dataframe information")
print(data.info())
# Out:
# Dataframe information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          234 non-null    object
#  1   rank             234 non-null    int64
#  2   area             234 non-null    float64
#  3   landAreaKm       234 non-null    float64
#  4   netChange        226 non-null    float64
#  5   growthRate       234 non-null    float64
#  6   worldPercentage  228 non-null    float64
#  7   density          234 non-null    float64
#  8   place            234 non-null    int64
#  9   pop2000          234 non-null    int64
#  10  pop2010          234 non-null    int64
#  11  pop2022          234 non-null    int64
#  12  pop2023          234 non-null    int64
#  13  pop2030          234 non-null    int64
#  14  pop2050          234 non-null    int64
# dtypes: float64(6), int64(8), object(1)
# memory usage: 27.6+ KB
# ...

# %% [markdown]
# **Inference:**

# %% [markdown]
# We can see that the dataset contains 15 columns and 234 rows.

# %% [markdown]
# **3. Removing Missing Values**

# %%
data = pd.read_csv('countries_table.csv')
#printing the nan values
print("Before Removing nan Values")
print(data.info())
#removing the nan values
data.dropna(inplace=True)
print("After Removing nan Values")
print(data.info())
data.to_csv('after_drop_countries_table.csv',index=False)
# Out:
# Before Removing nan Values
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          234 non-null    object
#  1   rank             234 non-null    int64
#  2   area             234 non-null    float64
#  3   landAreaKm       234 non-null    float64
#  4   netChange        226 non-null    float64
#  5   growthRate       234 non-null    float64
#  6   worldPercentage  228 non-null    float64
#  7   density          234 non-null    float64
#  8   place            234 non-null    int64
#  9   pop2000          234 non-null    int64
#  10  pop2010          234 non-null    int64
#  11  pop2022          234 non-null    int64
#  12  pop2023          234 non-null    int64
#  13  pop2030          234 non-null    int64
#  14  pop2050          234 non-null    int64
# dtypes: float64(6), int64(8), object(1)
# ...

# %% [markdown]
# **Inference:**
#
# After removing missing values we can see that the dataset contains 15 columns and 225 rows.

# %% [markdown]
# **4. Removing Duplicates**

# %%
data = pd.read_csv('countries_table.csv')
#Find the duplicate values
duplicate_rows = data.duplicated()
#Printing the no of duplicate rows
print("Before Removing Number of duplicate rows:", duplicate_rows.sum())
print(data[duplicate_rows])
#Removing duplicate values
data.drop_duplicates(inplace=True)
#Find the duplicate values
duplicate_rows = data.duplicated()
#Printing the no of duplicate rows
print("After Removing Number of duplicate rows:", duplicate_rows.sum())
print(data[duplicate_rows])
# Out:
# Before Removing Number of duplicate rows: 0
# Empty DataFrame
# Columns: [country, rank, area, landAreaKm, netChange, growthRate, worldPercentage, density, place, pop2000, pop2010, pop2022, pop2023, pop2030, pop2050]
# Index: []
# After Removing Number of duplicate rows: 0
# Empty DataFrame
# Columns: [country, rank, area, landAreaKm, netChange, growthRate, worldPercentage, density, place, pop2000, pop2010, pop2022, pop2023, pop2030, pop2050]
# Index: []

# %% [markdown]
# **Inference:**
#
# We can see that the dataset does not contain any duplicate value.

# %% [markdown]
# **In Database (After cleaning the data)**

# %%
data = pd.read_csv('after_drop_countries_table.csv')
print("Dataframe information")
print(data.info())
print("Dataframe Description")
print(data.describe())
# Out:
# Dataframe information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          225 non-null    object
#  1   rank             225 non-null    int64
#  2   area             225 non-null    float64
#  3   landAreaKm       225 non-null    float64
#  4   netChange        225 non-null    float64
#  5   growthRate       225 non-null    float64
#  6   worldPercentage  225 non-null    float64
#  7   density          225 non-null    float64
#  8   place            225 non-null    int64
#  9   pop2000          225 non-null    int64
#  10  pop2010          225 non-null    int64
#  11  pop2022          225 non-null    int64
#  12  pop2023          225 non-null    int64
#  13  pop2030          225 non-null    int64
#  14  pop2050          225 non-null    int64
# dtypes: float64(6), int64(8), object(1)
# memory usage: 26.5+ KB
# ...

# %% [markdown]
# **Inference:**
#
# After cleaning the dataset we see that the dataset contains 15 columns and 225 rows.
# The statistical summary of the dataset gives us the following information:
#
# 1. The mean population of 2023 is 3.574904e+07.
# 2. The minimum population of 1.139600e+04.
# 3. The maximum population of 2023 is 1.428628e+09.
# 4. The standard deviation of population of 2023 is 1.221.399430e+08.
# 5. The 25th percentile of population of 2023 is 6.264850e+05.
# 6. The 50th percentile of population of 2023 is 6.106869e+06.
# 7. The 75th percentile of population of 2023 is 2.392328e+07.

# %% [markdown]
# ## Finding Answers with the Data Using Visualizations

# %% [markdown]
# **Questions of data analysis**

# %% [markdown]
# Q1. Top 10 Max. Populated Countries Of The World\
# Q2. Top 10 Max. Area Oriented Countries Of The World\
# Q3. Top 10 Max. Land area Oriented Countries Of The World\
# Q4. Net Changes(%) In Population of Top 10 Countries Of The World\
# Q5. World Population Growth Rate by each Countries\
# Q6. Population Growth Percentage of World contributed By Each Countries\
# Q7. which country has the highest population density\
# Q8. Population Database Of 2023's\
# Q9. Visually represent the trends of population of India of those years\
# Q10. Visually representation the trends of population of world in the years 2000's, 2010's, 2020's, 2022's, 2023's\
# Q11. Predicted Population  Database Of 2030's,2050's and show Top 5 Max. Populated Countries Of The World

# %% [markdown]
# ##  Exploratory Data Analysis (EDA)

# %% [markdown]
# we all know world population database is a large amount of data. To know the characteristics of this database at a glance, we highlight some important topics of the database just like-
#
# **Q1. Top 10 Max. Populated Countries Of The World**

# %%
dataset=pd.read_csv('after_drop_countries_table.csv')
dataset.groupby('country')['rank'].sum().sort_values(ascending=True).head(10)
# Out:
# country
# India             1
# China             2
# United States     3
# Indonesia         4
# Pakistan          5
# Nigeria           6
# Brazil            7
# Bangladesh        8
# Russia            9
# Mexico           10
# Name: rank, dtype: int64

# %% [markdown]
# **Inference:**
#
# We can see that the max populated country is India all over The World.

# %% [markdown]
# **Q2. Top 10 Max. Area Oriented Countries Of The World**

# %%
colors = ['red', 'orange', 'brown', 'pink','yellow','green','violet','blue','purple','seagreen']
dataset.groupby('country')['area'].sum().sort_values(ascending=False).head(10).plot(kind='bar',xlabel='country',ylabel='Area Per sq.Km',title='Top 10 Max. Area Oriented Countries Of The World',color=colors)
# Out:
# <Axes: title={'center': 'Top 10 Max. Area Oriented Countries Of The World'}, xlabel='country', ylabel='Area Per sq.Km'>

# %% [markdown]
# **Inference:**
#
# From the graph we just plotted we can see that The largest country in the world is Russia with a total area of 17098242 sq.km.

# %% [markdown]
# **Q3. Top 10 Max. Land area Oriented Countries Of The World**

# %%
colors = ['red', 'brown', 'purple', 'pink','yellow','green','violet','blue','orange','seagreen']
dataset.groupby('country')['landAreaKm'].sum().sort_values(ascending=False).head(10).plot(kind='bar',xlabel='country',ylabel='Land Area Per sq.Km',title=' Top 10 Max. Land area Oriented Countries Of The World',color=colors)
# Out:
# <Axes: title={'center': ' Top 10 Max. Land area Oriented Countries Of The World'}, xlabel='country', ylabel='Land Area Per sq.Km'>

# %% [markdown]
# **Inference:**
#
# From the graph we just plotted we can see that The largest country in the world is Russia with a total Land area of 16376870 sq.km.

# %% [markdown]
# ## Trend Analysis

# %% [markdown]
# Here, we show some changes in Net changes, Growth rate of these top 10 countries, top 10 Populated Countries in 2023,trends of Population of World in the years 2000's, 2010's, 2020's, 2022's, 2023's, trends of Population of India of those years-
#
# **Q4. Net Changes(%) In Population of Top 10 Countries Of The World**

# %%
colors = ['red', 'orange', 'brown', 'purple','blue','green','yellow','violet','pink','seagreen']
dataset.groupby('country')['netChange'].sum().sort_values(ascending=False).head(10).plot(kind='bar',xlabel='country',ylabel='Net Change %',title='  Net Changes(%) In Population of Top 10 Countries Of The World',color=colors)
# Out:
# <Axes: title={'center': '  Net Changes(%) In Population of Top 10 Countries Of The World'}, xlabel='country', ylabel='Net Change %'>

# %% [markdown]
# **Inference:**
#
# **India** has maximum contribution in net changes(%) of the World Population.

# %% [markdown]
# **Q5.World Population Growth Rate  by each Countries**

# %%
dataset.groupby('country')['growthRate'].sum().sort_values(ascending=False).plot(kind='line',xlabel='country',ylabel='Growth Rate',title='World Population Growth Rate by each countries')
# Out:
# <Axes: title={'center': 'World Population Growth Rate by each countries'}, xlabel='country', ylabel='Growth Rate'>

# %% [markdown]
# **Inference:**
#
# From the graph we can see that Syria has the highest population growth rate of 4.98%.

# %% [markdown]
# **Q6.Population Growth Percentage of World contributed By Each Countries**

# %%
dataset.groupby('country')['worldPercentage'].sum().sort_values(ascending=False).head(5).plot(kind='pie', autopct='%1.1f%%',title='World Population Growth Rate')
# Out:
# <Axes: title={'center': 'World Population Growth Rate'}, ylabel='worldPercentage'>

# %% [markdown]
# **Inference:**
#
# India has maximum contributionn in growth percentage of world population.

# %% [markdown]
# **Q7. which country has the highest population density**

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
data = gpd.read_file('countries_table.csv')
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world = world.merge(dataset, how='left', left_on='name', right_on='country')
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
world.boundary.plot(ax=ax)
world.plot(column='density', ax=ax, legend=True, legend_kwds={'label': "Population Density", 'orientation': "horizontal"})
plt.title('World Population Density Map')
plt.show()
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_1224\1611722758.py:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# **Inference:**
#
# The highest population density country is **Macau**.

# %% [markdown]
# **Q8. Population Database Of 2023's**

# %%
colors = ['red', 'orange', 'brown', 'purple','blue','green','yellow','violet','pink','seagreen']
dataset.groupby('country')['pop2023'].sum().sort_values(ascending=False).head(10).plot(kind='bar',xlabel='country',ylabel='Billion',title=' Top 10 populated countries of 2023',color=colors)
# Out:
# <Axes: title={'center': ' Top 10 populated countries of 2023'}, xlabel='country', ylabel='Billion'>

# %% [markdown]
# **Q9. Visually represent the trends of population of India of those years**

# %%
india_data = dataset[dataset['country'] == 'India']
years = ['2000', '2010', '2022', '2023']
population_values = india_data[['pop2000', 'pop2010', 'pop2022', 'pop2023']].values[0]
plt.plot(years, population_values, marker='o', label='India', color='orange')
plt.xlabel('Year')
plt.ylabel('Population(Billion)')
plt.title('Population Trends of India (2000, 2010, 2022, 2023)')
plt.legend()
plt.show()

# %% [markdown]
# **Inference:**
#
# India's population growth trend is to increase at a steady rate from 2000 to 2022 and then decline slightly from 2022 to 2023.

# %% [markdown]
# **Q10. Visually representation the Trends of Population of World in the years 2000's, 2010's, 2020's, 2022's, 2023's**

# %%
dataset['Total_Population_2000'] = dataset['pop2000'].sum()
dataset['Total_Population_2010'] = dataset['pop2010'].sum()
dataset['Total_Population_2022'] = dataset['pop2022'].sum()
dataset['Total_Population_2023'] = dataset['pop2023'].sum()
years = ['2000', '2010', '2022', '2023']
plt.plot(years,[dataset['Total_Population_2000'].values[0], dataset['Total_Population_2010'].values[0], dataset['Total_Population_2022'].values[0], dataset['Total_Population_2023'].values[0]], marker='o', label='Total Population(Billion)')
plt.xlabel('Year')
plt.ylabel('Total Population(Billion)')
plt.title('World Total Population Trends (2000, 2010, 2022, 2023)')
plt.legend()
plt.show()

# %% [markdown]
# **Inference:**
#
# World's population growth trend is increase afrom 2000 to 2022 and then decline slightly from 2022 to 2023.

# %% [markdown]
# ## Predictive Modelling

# %% [markdown]
# As the world population grows at this rate, we can predict a world population of 2030 and 2050. Here the graph

# %%
dataset['Total_Population_2000'] = dataset['pop2000'].sum()
dataset['Total_Population_2010'] = dataset['pop2010'].sum()
dataset['Total_Population_2022'] = dataset['pop2022'].sum()
dataset['Total_Population_2023'] = dataset['pop2023'].sum()
dataset['Total_Population_2030'] = dataset['pop2030'].sum()
dataset['Total_Population_2050'] = dataset['pop2050'].sum()
years = ['2000', '2010', '2022', '2023','2030','2050']
plt.plot(years,[dataset['Total_Population_2000'].values[0], dataset['Total_Population_2010'].values[0], dataset['Total_Population_2022'].values[0], dataset['Total_Population_2023'].values[0], dataset['Total_Population_2030'].values[0], dataset['Total_Population_2050'].values[0]], marker='o', label='Total Population(Billion)',color='red')
plt.xlabel('Year')
plt.ylabel('Total Population(Billion)')
plt.title('World Total Population Trends (2000, 2010, 2022, 2023,2030,2050)')
plt.legend()
plt.show()

# %% [markdown]
# **Inference:**
# By looking at the population growth rate trend between 2000 and 2023, we predicted that the trend of population growth in 2030 and 2050 will further increase.

# %% [markdown]
# **Q11. Predicted Population Database Of 2030's,2050's and show Top 5 Max. Populated Countries Of The World**

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
Population_2023 = dataset.groupby('country')['pop2023'].sum().sort_values(ascending=False).head(5)
axs[0, 0].bar(Population_2023.index, Population_2023)
axs[0, 0].set_title('Population of 2023')
axs[0, 0].set_xlabel('Country')
axs[0, 0].set_ylabel('Billion')
Population_2030 = dataset.groupby('country')['pop2030'].sum().sort_values(ascending=False).head(5)
axs[0, 1].bar(Population_2030.index, Population_2030)
axs[0, 1].set_title('Population of 2030')
axs[0, 1].set_xlabel('Country')
axs[0, 1].set_ylabel('Billion')
Population_2050 = dataset.groupby('country')['pop2050'].sum().sort_values(ascending=False).head(5)
axs[1, 0].bar(Population_2050.index, Population_2050)
axs[1, 0].set_title('Population of 2050')
axs[1, 0].set_xlabel('Country')
axs[1, 0].set_ylabel('Billion')
axs[1, 1].axis('off')
# Adjust layout for better appearance
plt.tight_layout()
# Show the plots
plt.show()

# %% [markdown]
# **Inference:**
#
# Compare to the population growth of 2023 we can see that in 2030 and 2050 **India** and **China** become the most populated countries in The World.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In conclusion, the analysis of world population data has revealed significant trends and insights into global demographics. India emerges as the most populated country, contributing substantially to net changes in the world population. Russia stands out as the largest country by both total area and land area.
#
# The examination of population growth rates highlights Syria as a noteworthy country experiencing a high growth rate, while India consistently contributes significantly to the overall growth percentage of the world population. Macau, with its high population density, exemplifies the challenges faced by densely populated regions.
#
# The visual representation of population trends for India indicates steady growth until 2022, followed by a slight decline, while the world experiences a similar pattern. Predictions for 2030 and 2050 suggest a continued global population increase, with India and China anticipated to become the most populated countries.
#
# The constant trajectory of increasing population growth globally raises concerns about sustainable resource management, environmental impact, and the need for effective policies to address the challenges associated with overpopulation. It calls for collaborative efforts on a global scale to ensure a balance between population growth and the well-being of societies, emphasizing the importance of strategic planning and sustainable development practices to navigate the complexities of an expanding world population.
#
# The Advantages Of World Population :-
#
# 1. More people leads to greater human capital.
# 2. Higher economic growth.
# 3. Economies of scale.
# 4. The efficiency of higher population density.
# 5. The improved demographic structure of society.

# %% [markdown]
# The Disadvantages of World Population:-
#
# 1. Cost to the environment.
# 2. Congestion.
# 3. Water shortages.
# 4. Generating unsustainable waste.

# %% [markdown]
# ## Acknowledgement

# %% [markdown]
# We extend our heartfelt gratitude to our esteemed mentor, **Mr. Suramya Biswas**, for his unwavering guidance and support throughout the development of this Python project. Our sincere appreciation goes to our fellow team members at **Anudip Foundation** —[Sanchita Mohanta ,Sunita Chatterjee ,Kaushiki Chatterjee , Srijita Ghosh], whose collaborative efforts and dedication significantly contributed to the success of this world population data analysis project. Special thanks to Anudip Foundation for providing us with the platform to explore and learn. This project stands as a testament to the collective effort and commitment of our team.

# %% [markdown]
# # THANK YOU
